# %%
from mesa import Agent, Model
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector
import seaborn as sns
import matplotlib.pyplot as plt

# Has multi-dimensional arrays and matrices. Has a large collection of
# mathematical functions to operate on these arrays.
import numpy as np

# Data manipulation and analysis.
import pandas as pd

# %%
class BaseAgent(Agent):
    def __init__(self, model, stamina):
        super().__init__(model)
        self.stamina = stamina

    def move_towards(self, target_pos):
        """Move towards the target position (target_pos is a tuple)."""
        x, y = self.pos
        target_x, target_y = target_pos

        # Move horizontally towards the target
        if x < target_x:
            x += 1  # Move right
        elif x > target_x:
            x -= 1  # Move left

        # Move vertically towards the target
        if y < target_y:
            y += 1  # Move down
        elif y > target_y:
            y -= 1  # Move up

        # Update the position on the grid
        self.model.grid.move_agent(self, (x, y))
        print(f"{type(self).__name__} moved to {self.pos}.")

    def move(self):
        """Move randomly to a neighboring cell."""
        # Get all possible neighboring positions
        possible_moves = self.model.grid.get_neighborhood(self.pos, moore=True, include_center=False)
        # Choose a random move from the available positions
        new_pos = self.random.choice(possible_moves)
        # Update the position on the grid
        self.model.grid.move_agent(self, new_pos)
        print(f"{type(self).__name__} moved to {new_pos}.")

    def rest(self):
        """Rest to regain stamina."""
        max_stamina = 100  # Define maximum stamina
        if self.stamina < max_stamina:
            self.stamina = min(self.stamina + 10, max_stamina)
            print(f"{type(self).__name__} resting. Stamina: {self.stamina}/{max_stamina}")

    def step(self):
        """Define agent behavior during each step."""
        if self.model.is_night:
            # Move towards the lifepod if it's night
            lifepod_pos = self.model.lifepod_location
            if self.pos != lifepod_pos:  # If not already at the lifepod
                self.move_towards(lifepod_pos)
            else:
                print(f"{type(self).__name__} resting at lifepod during night at {self.pos}.")
                self.rest()
        else:
            # Define day behavior in derived classes
            print(f"{type(self).__name__} acting during the day.")

# %%
class Miner(BaseAgent):
    def __init__(self, model, stamina=69):
        super().__init__(model, stamina)
        self.iron = 0

    def step(self):
        """Perform the miner's actions for each step."""
        if self.model.is_night:  # Check if it's nighttime
            lifepod = self.get_lifepod()
            if lifepod:
                print(f"Miner at {self.pos} moving towards Lifepod at {lifepod.pos} during the night.")
                if self.pos != lifepod.pos:  # If not at the Lifepod, move towards it
                    self.move_towards(lifepod.pos)
                else:
                    print(f"Miner at {self.pos} is staying at the Lifepod during the night.")
        else:  # Daytime actions
            if self.stamina > 0:
                nearest_drill = self.find_nearest_drill()

                if nearest_drill:
                    print(f"Miner at {self.pos} moving towards drill at {nearest_drill.pos}")
                    
                    # Check if miner is within one step of the drill
                    if self.is_near_drill(nearest_drill):
                        print(f"Miner is near the drill at {nearest_drill.pos}. Starting to mine.")
                        self.use_drill(nearest_drill)
                    else:
                        # Move towards the drill
                        self.move_towards(nearest_drill.pos)
                else:
                    print("No drill found.")
                    self.rest()  # If no drill is found, the miner rests
            else:
                self.rest()  # Rest when stamina is depleted

    def is_near_drill(self, drill):
        """Check if the miner is adjacent to the drill (within one step)."""
        return abs(self.pos[0] - drill.pos[0]) <= 1 and abs(self.pos[1] - drill.pos[1]) <= 1

    def find_nearest_drill(self):
        """Find the nearest drill on the grid."""
        drills = [agent for agent in self.model.agents if isinstance(agent, Drill) and not agent.is_broken()]
        print(f"Available drills: {[drill.pos for drill in drills]}")  # Debug: print available drills
        if not drills:
            return None
        # Find the drill with the minimum Manhattan distance
        nearest_drill = min(drills, key=lambda drill: abs(drill.pos[0] - self.pos[0]) + abs(drill.pos[1] - self.pos[1]))
        print(f"Nearest drill found at {nearest_drill.pos}")  # Debug: print nearest drill
        return nearest_drill
        
    def use_drill(self, drill):
        """Use the drill to collect resources."""
        if drill.fuel > 0 and not drill.is_broken():
            print("Drill is functional, starting mining.")
            drill.mine()  # The drill mines and updates its fuel, health, and iron state
            self.iron += 3  # Miner collects iron
            print(f"Mining... Total Iron: {self.iron}")
            
            # After collecting iron, store it in the Lifepod
            lifepod = self.get_lifepod() 
            if lifepod:
                lifepod.store_iron(3)  # Store 3 iron in the Lifepod

            self.stamina -= 1  # Miner consumes stamina each time it mines
        else:
            print("Drill cannot be used due to lack of fuel or health.")
            
    def rest(self):
        """Regain stamina when resting."""
        super().rest()  # Call the base class's rest method
        print(f"Miner at {self.pos} is resting to regain stamina.")  # Print when the miner is resting

    def get_lifepod(self):
        """Retrieve the Lifepod in the model."""
        # Assuming you have only one Lifepod in your model, find it
        for agent in self.model.agents:
            if isinstance(agent, Lifepod):
                return agent
        return None

# %%
class Engineer(BaseAgent):
    def __init__(self, model, stamina=69):
        super().__init__(model, stamina)

    def step(self):
        """Define the engineer's actions for each step."""
        if self.model.is_night:  # Follow the BaseAgent's night behavior
            super().step()
            return

        if self.stamina > 0:
            # Check for a nearby broken drill and move towards it if necessary
            nearest_broken_drill = self.find_nearest_broken_drill()
            if nearest_broken_drill:
                print(f"Engineer at {self.pos} moving towards broken drill at {nearest_broken_drill.pos}.")
                if self.is_near_drill(nearest_broken_drill):
                    self.repair(nearest_broken_drill)  # Repair the drill if near
                else:
                    self.move_towards(nearest_broken_drill.pos)  # Move towards the broken drill
            else:
                self.move()  # Move randomly if no broken drill is found
                print(f"Engineer at {self.pos} is moving randomly.")
        else:
            self.rest()  # Rest when stamina is depleted
            print(f"Engineer at {self.pos} is resting to regain stamina.")

    def find_nearest_broken_drill(self):
        """Find the nearest broken drill on the grid."""
        drills = [
            agent for agent in self.model.agents
            if isinstance(agent, Drill) and agent.is_broken()
        ]
        if drills:
            nearest_drill = min(drills, key=lambda drill: abs(self.pos[0] - drill.pos[0]) + abs(self.pos[1] - drill.pos[1]))
            print(f"Nearest broken drill found at {nearest_drill.pos}.")
            return nearest_drill
        print("No broken drills found.")
        return None

    def is_near_drill(self, drill):
        """Check if the engineer is adjacent to the drill (within one step)."""
        return abs(self.pos[0] - drill.pos[0]) <= 1 and abs(self.pos[1] - drill.pos[1]) <= 1

    def repair(self, drill):
        """Repair the drill."""
        if drill.is_broken():
            print(f"Engineer at {self.pos} repairing drill at {drill.pos}.")
            drill.repair()
            self.stamina = max(0, self.stamina - 10)  # Reduce stamina but ensure it doesn't go below 0
        else:
            print(f"Drill at {drill.pos} is not broken.")

    def rest(self):
        """Regain stamina when resting."""
        super().rest()  # Call the base class's rest method
        if self.stamina < 100:
            self.stamina = min(100, self.stamina + 10)  # Increment stamina towards full
            print(f"Engineer at {self.pos} is resting. Current stamina: {self.stamina}.")

# %%
class Drill(Agent):
    def __init__(self, model, max_fuel=69, max_health=69):
        super().__init__(model)
        self.fuel = max_fuel
        self.iron = 0
        self.health = max_health

    def is_broken(self):
        """Check if the drill is broken (out of health or fuel)."""
        return self.health <= 0 or self.fuel <= 0  # Drill is considered broken if either fuel or health is zero

    def repair(self):
        """Repair the drill to full health and reset fuel."""
        self.health = 69  # Full health after repair
        self.fuel = 69  # Reset fuel after repair

    def mine(self):
        """Simulate mining using the drill."""
        if not self.is_broken():
            # Perform mining if the drill is functional
            self.fuel -= 1  # Decrease fuel
            self.iron += 3  # Increase iron
            self.health = max(0, self.health - 1)  # Decrease health, ensure it's non-negative
            print(f"Mining... Drill Fuel: {self.fuel}, Drill Health: {self.health}, Iron: {self.iron}")
        else:
            print("Drill is out of fuel or broken!")

# %%
class Farmer(BaseAgent):
    def __init__(self, model, stamina=69):
        super().__init__(model, stamina)

    def step(self):
        if self.model.is_night:  # Check if it's nighttime
            lifepod = self.get_lifepod()
            if lifepod:
                print(f"Farmer at {self.pos} moving towards Lifepod at {lifepod.pos} during the night.")
                if self.pos != lifepod.pos:  # If not at the Lifepod, move towards it
                    self.move_towards(lifepod.pos)
                else:
                    print(f"Farmer at {self.pos} is staying at the Lifepod during the night.")
        else:  # Daytime actions
            if self.stamina > 0:
                nearest_greenhouse = self.find_nearest_greenhouse()  # Find the nearest greenhouse
                
                if nearest_greenhouse:
                    # Move towards the greenhouse until the farmer is near it
                    if not self.near_greenhouse(nearest_greenhouse):
                        self.move_towards(nearest_greenhouse.pos)
                        print(f"Farmer at {self.pos} is moving towards greenhouse at {nearest_greenhouse.pos}.")
                    else:
                        self.collect_food(nearest_greenhouse)  # Collect food if near the greenhouse
                else:
                    print("No greenhouse found.")
            else:
                self.rest()  # Rest when stamina is depleted

    def collect_food(self, greenhouse):
        """Collect food from the greenhouse and store in the Lifepod."""
        if greenhouse.food > 0:
            collected_food = 5  # The farmer collects 5 units of food
            greenhouse.food -= collected_food  # Reduce food from the greenhouse
            print(f"Farmer collected {collected_food} food from greenhouse at {self.pos}.")
            
            lifepod = self.get_lifepod()
            if lifepod:
                lifepod.store_food(collected_food)  # Store collected food in the Lifepod

            # Decrease stamina only when collecting food
            self.stamina = max(self.stamina - 5, 0)  # Decrease stamina for collecting food
        else:
            print(f"Greenhouse at {self.pos} has no food left.")

    def find_nearest_greenhouse(self):
        """Find the nearest greenhouse on the grid."""
        greenhouses = [agent for agent in self.model.agents if isinstance(agent, Greenhouse)]
        if greenhouses:
            nearest_greenhouse = min(greenhouses, key=lambda greenhouse: abs(greenhouse.pos[0] - self.pos[0]) + abs(greenhouse.pos[1] - self.pos[1]))
            return nearest_greenhouse
        return None

    def near_greenhouse(self, greenhouse):
        """Check if the farmer is near a specific greenhouse."""
        return self.pos == greenhouse.pos
    
    def get_lifepod(self):
        """Retrieve the Lifepod in the model."""
        for agent in self.model.agents:
            if isinstance(agent, Lifepod):
                return agent
        return None

# %%
class Greenhouse(Agent):
    def __init__(self, model, max_food=100, food_add_rate=10):
        super().__init__(model)
        self.food = 0
        self.max_food = max_food
        self.food_add_rate = food_add_rate  # Rate at which food is added to the greenhouse

    def step(self):
        # The greenhouse adds food at a set rate, up to the max capacity
        self.add_food(self.food_add_rate)

    def add_food(self, amount):
        """Add food to the greenhouse, respecting the max_food limit."""
        if self.food + amount <= self.max_food:
            self.food += amount
            print(f"Greenhouse added {amount} food. Total food: {self.food}")
        else:
            self.food = self.max_food
            print(f"Greenhouse food reached max capacity: {self.food}")

# %%
class Lifepod(Agent):
    def __init__(self, model):
        super().__init__(model)
        self.food = 20  # Starting food in the Lifepod
        self.iron = 0  # Starting iron in the Lifepod

    def store_iron(self, amount):
        """Store the given amount of iron in the Lifepod."""
        self.iron += amount
        print(f"Lifepod now has {self.iron} iron.")

    def get_iron(self):
        """Get the current amount of iron in the Lifepod."""
        return self.iron

    def store_food(self, amount):
        """Store the given amount of food in the Lifepod."""
        self.food += amount
        print(f"Lifepod now has {self.food} food.")

    def get_food(self):
        """Get the current amount of food in the Lifepod."""
        return self.food

# %%
class SurvivalModel(Model):
    """The goddamn model"""
    
    def __init__(self, width, height, seed=69):
        super().__init__(seed=seed)
        self.grid = MultiGrid(width, height, False)
        
        # Set lifepod location at the center of the grid
        self.lifepod_location = (width // 2, height // 2)
        
        # Create and place the Lifepod
        self.lifepod = Lifepod(self)
        self.grid.place_agent(self.lifepod, self.lifepod_location)
        
        # Create and place worker agents at the lifepod location
        self.miner = Miner(self)
        self.engineer = Engineer(self)
        self.farmer = Farmer(self)
        
        for agent in [self.miner, self.engineer, self.farmer]:
            self.grid.place_agent(agent, self.lifepod_location)

        # Set fixed coordinates for the Drill and Greenhouse for simplicity
        self.drill_location = (self.lifepod_location[0] + 4, self.lifepod_location[1] + 4)  # Example: place drill 2 units to the right of the lifepod
        self.greenhouse_location = (self.lifepod_location[0] - 4, self.lifepod_location[1]+4)  # Example: place greenhouse 4 units to the left of the lifepod
        
        # Create and place resource-generating structures at these specific locations
        self.drill = Drill(self)
        self.greenhouse = Greenhouse(self)
        
        # Ensure drill and greenhouse are not placed on the lifepod location
        if self.drill_location != self.lifepod_location:
            self.grid.place_agent(self.drill, self.drill_location)
        
        if self.greenhouse_location != self.lifepod_location:
            self.grid.place_agent(self.greenhouse, self.greenhouse_location)
          
        # Day-night cycle variables
        self.time_step = 0
        self.is_night = False
        
        # Create DataCollector to track model state
        self.datacollector = DataCollector(
            model_reporters={
                "Total Food": lambda m: m.lifepod.food,
                "Total Iron": lambda m: m.lifepod.iron,  # Track the iron count in the Lifepod
                "Drill Health": lambda m: m.drill.health,
                "Drill Fuel": lambda m: m.drill.fuel,
                "Greenhouse Food": lambda m: m.greenhouse.food,
                "Miner Stamina": lambda m: m.miner.stamina,
                "Engineer Stamina": lambda m: m.engineer.stamina,
                "Farmer Stamina": lambda m: m.farmer.stamina,
                "Is Night": lambda m: m.is_night,
                "Cell Contents": self.record_cell_contents
            }
        )

    def record_cell_contents(self):
        """Record the contents of each cell in the grid."""
        cell_data = {}
        for cell_contents, (x, y) in self.grid.coord_iter():
            cell_data[(x, y)] = [type(agent).__name__ for agent in cell_contents]
        return cell_data
    
    def toggle_day_night(self):
        """Toggle the day-night cycle based on the time step."""
        # Day lasts for 30 iterations, night lasts for 15 iterations
        if self.time_step % 45 < 30:
            self.is_night = False
        else:
            self.is_night = True
        print(f"Time Step: {self.time_step}, Night: {self.is_night}")
    
    def step(self):
        """Advance the model by one step."""
        # Update the day-night cycle
        self.toggle_day_night()
        
        # Collect data and advance agents
        self.datacollector.collect(self)
        self.agents.shuffle_do("step")
        
        # Increment the time step
        self.time_step += 1

# %%
model = SurvivalModel(10, 10)
for _ in range(100):  
    model.step()
# Out:
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (5, 5) moving towards drill at (9, 9)
# Miner moved to (6, 6)
# Engineer at (6, 4) is moving randomly.
# Farmer moved to (4, 5)
# Farmer at (4, 5) is moving towards greenhouse at (1, 5).
# Greenhouse added 10 food. Total food: 10
# Greenhouse added 10 food. Total food: 20
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (6, 6) moving towards drill at (9, 9)
# Miner moved to (7, 7)
# Farmer moved to (3, 5)
# Farmer at (3, 5) is moving towards greenhouse at (1, 5).
# Engineer at (7, 5) is moving randomly.
# Greenhouse added 10 food. Total food: 30
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (7, 7) moving towards drill at (9, 9)
# Miner moved to (8, 8)
# Farmer moved to (2, 5)
# Farmer at (2, 5) is moving towards greenhouse at (1, 5).
# Engineer at (8, 5) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 68, Drill Health: 68, Iron: 3
# Mining... Total Iron: 3
# Lifepod now has 3 iron.
# Greenhouse added 10 food. Total food: 40
# Engineer at (7, 6) is moving randomly.
# Farmer moved to (1, 5)
# Farmer at (1, 5) is moving towards greenhouse at (1, 5).
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 25 food.
# Greenhouse added 10 food. Total food: 45
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 67, Drill Health: 67, Iron: 6
# Mining... Total Iron: 6
# Lifepod now has 6 iron.
# Engineer at (8, 6) is moving randomly.
# Greenhouse added 10 food. Total food: 55
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 66, Drill Health: 66, Iron: 9
# Mining... Total Iron: 9
# Lifepod now has 9 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 30 food.
# Engineer at (7, 5) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 35 food.
# Engineer at (7, 4) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 65, Drill Health: 65, Iron: 12
# Mining... Total Iron: 12
# Lifepod now has 12 iron.
# Greenhouse added 10 food. Total food: 55
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 40 food.
# Greenhouse added 10 food. Total food: 60
# Engineer at (8, 3) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 64, Drill Health: 64, Iron: 15
# Mining... Total Iron: 15
# Lifepod now has 15 iron.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 63, Drill Health: 63, Iron: 18
# Mining... Total Iron: 18
# Lifepod now has 18 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 45 food.
# Engineer at (7, 3) is moving randomly.
# Greenhouse added 10 food. Total food: 65
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 50 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 62, Drill Health: 62, Iron: 21
# Mining... Total Iron: 21
# Lifepod now has 21 iron.
# Engineer at (6, 4) is moving randomly.
# Greenhouse added 10 food. Total food: 70
# Engineer at (5, 5) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 61, Drill Health: 61, Iron: 24
# Mining... Total Iron: 24
# Lifepod now has 24 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 55 food.
# Greenhouse added 10 food. Total food: 75
# Engineer at (6, 5) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 60, Drill Health: 60, Iron: 27
# Mining... Total Iron: 27
# Lifepod now has 27 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 60 food.
# Greenhouse added 10 food. Total food: 80
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 59, Drill Health: 59, Iron: 30
# Mining... Total Iron: 30
# Lifepod now has 30 iron.
# Engineer at (7, 4) is moving randomly.
# Greenhouse added 10 food. Total food: 90
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 65 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 58, Drill Health: 58, Iron: 33
# Mining... Total Iron: 33
# Lifepod now has 33 iron.
# Engineer at (8, 5) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 70 food.
# Greenhouse added 10 food. Total food: 90
# Engineer at (9, 6) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 57, Drill Health: 57, Iron: 36
# Mining... Total Iron: 36
# Lifepod now has 36 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 75 food.
# Greenhouse added 10 food. Total food: 95
# Engineer at (9, 7) is moving randomly.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 80 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 56, Drill Health: 56, Iron: 39
# Mining... Total Iron: 39
# Lifepod now has 39 iron.
# Engineer at (8, 6) is moving randomly.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 55, Drill Health: 55, Iron: 42
# Mining... Total Iron: 42
# Lifepod now has 42 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 85 food.
# Engineer at (7, 6) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 54, Drill Health: 54, Iron: 45
# Mining... Total Iron: 45
# Lifepod now has 45 iron.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 90 food.
# Greenhouse food reached max capacity: 100
# Engineer at (6, 6) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 53, Drill Health: 53, Iron: 48
# Mining... Total Iron: 48
# Lifepod now has 48 iron.
# Agent rested. Current stamina: 10
# Engineer at (7, 5) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 52, Drill Health: 52, Iron: 51
# Mining... Total Iron: 51
# Lifepod now has 51 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 95 food.
# Greenhouse food reached max capacity: 100
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 51, Drill Health: 51, Iron: 54
# Mining... Total Iron: 54
# Lifepod now has 54 iron.
# Engineer at (8, 6) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 100 food.
# Engineer at (7, 5) is moving randomly.
# Agent rested. Current stamina: 10
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 50, Drill Health: 50, Iron: 57
# Mining... Total Iron: 57
# Lifepod now has 57 iron.
# Engineer at (6, 5) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 105 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 49, Drill Health: 49, Iron: 60
# Mining... Total Iron: 60
# Lifepod now has 60 iron.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 110 food.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 48, Drill Health: 48, Iron: 63
# Mining... Total Iron: 63
# Lifepod now has 63 iron.
# Engineer at (7, 6) is moving randomly.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 47, Drill Health: 47, Iron: 66
# Mining... Total Iron: 66
# Lifepod now has 66 iron.
# Agent rested. Current stamina: 10
# Engineer at (6, 5) is moving randomly.
# Greenhouse food reached max capacity: 100
# Engineer at (7, 5) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 46, Drill Health: 46, Iron: 69
# Mining... Total Iron: 69
# Lifepod now has 69 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 115 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 45, Drill Health: 45, Iron: 72
# Mining... Total Iron: 72
# Lifepod now has 72 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 120 food.
# Engineer at (8, 6) is moving randomly.
# Greenhouse added 10 food. Total food: 100
# Greenhouse food reached max capacity: 100
# Agent rested. Current stamina: 10
# Engineer at (9, 5) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 44, Drill Health: 44, Iron: 75
# Mining... Total Iron: 75
# Lifepod now has 75 iron.
# Engineer at (0, 5) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 125 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 43, Drill Health: 43, Iron: 78
# Mining... Total Iron: 78
# Lifepod now has 78 iron.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 130 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 42, Drill Health: 42, Iron: 81
# Mining... Total Iron: 81
# Lifepod now has 81 iron.
# Greenhouse food reached max capacity: 100
# Engineer at (9, 6) is moving randomly.
# Agent rested. Current stamina: 10
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 41, Drill Health: 41, Iron: 84
# Mining... Total Iron: 84
# Lifepod now has 84 iron.
# Engineer at (8, 7) is moving randomly.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 40, Drill Health: 40, Iron: 87
# Mining... Total Iron: 87
# Lifepod now has 87 iron.
# Engineer at (9, 7) is moving randomly.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 135 food.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 140 food.
# Greenhouse added 10 food. Total food: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 39, Drill Health: 39, Iron: 90
# Mining... Total Iron: 90
# Lifepod now has 90 iron.
# Engineer at (0, 6) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 38, Drill Health: 38, Iron: 93
# Mining... Total Iron: 93
# Lifepod now has 93 iron.
# Greenhouse food reached max capacity: 100
# Engineer at (9, 7) is moving randomly.
# Agent rested. Current stamina: 10
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 37, Drill Health: 37, Iron: 96
# Mining... Total Iron: 96
# Lifepod now has 96 iron.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 145 food.
# Engineer at (8, 8) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 36, Drill Health: 36, Iron: 99
# Mining... Total Iron: 99
# Lifepod now has 99 iron.
# Greenhouse food reached max capacity: 100
# Engineer at (7, 8) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 150 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 35, Drill Health: 35, Iron: 102
# Mining... Total Iron: 102
# Lifepod now has 102 iron.
# Greenhouse food reached max capacity: 100
# Engineer at (7, 7) is moving randomly.
# Agent rested. Current stamina: 10
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 155 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 34, Drill Health: 34, Iron: 105
# Mining... Total Iron: 105
# Lifepod now has 105 iron.
# Greenhouse food reached max capacity: 100
# Engineer at (6, 6) is moving randomly.
# Engineer at (7, 7) is moving randomly.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 33, Drill Health: 33, Iron: 108
# Mining... Total Iron: 108
# Lifepod now has 108 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 160 food.
# Greenhouse food reached max capacity: 100
# Agent rested. Current stamina: 10
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 32, Drill Health: 32, Iron: 111
# Mining... Total Iron: 111
# Lifepod now has 111 iron.
# Engineer at (8, 8) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 165 food.
# Greenhouse food reached max capacity: 100
# Engineer at (7, 8) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 31, Drill Health: 31, Iron: 114
# Mining... Total Iron: 114
# Lifepod now has 114 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 170 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 30, Drill Health: 30, Iron: 117
# Mining... Total Iron: 117
# Lifepod now has 117 iron.
# Engineer at (7, 9) is moving randomly.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 29, Drill Health: 29, Iron: 120
# Mining... Total Iron: 120
# Lifepod now has 120 iron.
# Greenhouse food reached max capacity: 100
# Engineer at (7, 0) is moving randomly.
# Agent rested. Current stamina: 10
# Engineer at (8, 9) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 28, Drill Health: 28, Iron: 123
# Mining... Total Iron: 123
# Lifepod now has 123 iron.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 175 food.
# Engineer at (8, 0) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 27, Drill Health: 27, Iron: 126
# Mining... Total Iron: 126
# Lifepod now has 126 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 180 food.
# Greenhouse added 10 food. Total food: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 26, Drill Health: 26, Iron: 129
# Mining... Total Iron: 129
# Lifepod now has 129 iron.
# Engineer at (9, 1) is moving randomly.
# Agent rested. Current stamina: 10
# Greenhouse food reached max capacity: 100
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 185 food.
# Engineer at (8, 2) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 25, Drill Health: 25, Iron: 132
# Mining... Total Iron: 132
# Lifepod now has 132 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 190 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 24, Drill Health: 24, Iron: 135
# Mining... Total Iron: 135
# Lifepod now has 135 iron.
# Engineer at (9, 1) is moving randomly.
# Greenhouse added 10 food. Total food: 100
# Engineer at (0, 0) is moving randomly.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 23, Drill Health: 23, Iron: 138
# Mining... Total Iron: 138
# Lifepod now has 138 iron.
# Agent rested. Current stamina: 10
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 22, Drill Health: 22, Iron: 141
# Mining... Total Iron: 141
# Lifepod now has 141 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 195 food.
# Engineer at (1, 0) is moving randomly.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 200 food.
# Engineer at (2, 0) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 21, Drill Health: 21, Iron: 144
# Mining... Total Iron: 144
# Lifepod now has 144 iron.
# Greenhouse food reached max capacity: 100
# Agent rested. Current stamina: 10
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 20, Drill Health: 20, Iron: 147
# Mining... Total Iron: 147
# Lifepod now has 147 iron.
# Greenhouse food reached max capacity: 100
# Engineer at (2, 1) is moving randomly.
# Engineer at (2, 0) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 205 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 19, Drill Health: 19, Iron: 150
# Mining... Total Iron: 150
# Lifepod now has 150 iron.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 210 food.
# Greenhouse food reached max capacity: 100
# Engineer at (3, 1) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 18, Drill Health: 18, Iron: 153
# Mining... Total Iron: 153
# Lifepod now has 153 iron.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 17, Drill Health: 17, Iron: 156
# Mining... Total Iron: 156
# Lifepod now has 156 iron.
# Greenhouse food reached max capacity: 100
# Agent rested. Current stamina: 10
# Engineer at (4, 1) is moving randomly.
# Engineer at (5, 1) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 215 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 16, Drill Health: 16, Iron: 159
# Mining... Total Iron: 159
# Lifepod now has 159 iron.
# Greenhouse food reached max capacity: 100
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 15, Drill Health: 15, Iron: 162
# Mining... Total Iron: 162
# Lifepod now has 162 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 220 food.
# Engineer at (4, 1) is moving randomly.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 14, Drill Health: 14, Iron: 165
# Mining... Total Iron: 165
# Lifepod now has 165 iron.
# Engineer at (4, 0) is moving randomly.
# Agent rested. Current stamina: 10
# Engineer at (3, 0) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 13, Drill Health: 13, Iron: 168
# Mining... Total Iron: 168
# Lifepod now has 168 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 225 food.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 230 food.
# Engineer at (4, 9) is moving randomly.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 12, Drill Health: 12, Iron: 171
# Mining... Total Iron: 171
# Lifepod now has 171 iron.
# Greenhouse food reached max capacity: 100
# Agent rested. Current stamina: 10
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 11, Drill Health: 11, Iron: 174
# Mining... Total Iron: 174
# Lifepod now has 174 iron.
# Engineer at (3, 8) is moving randomly.
# Engineer at (2, 9) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 235 food.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 10, Drill Health: 10, Iron: 177
# Mining... Total Iron: 177
# Lifepod now has 177 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 240 food.
# Engineer at (1, 0) is moving randomly.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 9, Drill Health: 9, Iron: 180
# Mining... Total Iron: 180
# Lifepod now has 180 iron.
# Greenhouse food reached max capacity: 100
# Agent rested. Current stamina: 10
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 8, Drill Health: 8, Iron: 183
# Mining... Total Iron: 183
# Lifepod now has 183 iron.
# Engineer at (2, 1) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 245 food.
# Engineer at (3, 2) is moving randomly.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 7, Drill Health: 7, Iron: 186
# Mining... Total Iron: 186
# Lifepod now has 186 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 250 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 6, Drill Health: 6, Iron: 189
# Mining... Total Iron: 189
# Lifepod now has 189 iron.
# Engineer at (2, 1) is moving randomly.
# Greenhouse food reached max capacity: 100
# Agent rested. Current stamina: 10
# Greenhouse food reached max capacity: 100
# Engineer at (3, 1) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 5, Drill Health: 5, Iron: 192
# Mining... Total Iron: 192
# Lifepod now has 192 iron.
# Engineer at (3, 0) is moving randomly.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 255 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 4, Drill Health: 4, Iron: 195
# Mining... Total Iron: 195
# Lifepod now has 195 iron.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 3, Drill Health: 3, Iron: 198
# Mining... Total Iron: 198
# Lifepod now has 198 iron.
# Engineer at (3, 9) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 260 food.
# Greenhouse added 10 food. Total food: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 2, Drill Health: 2, Iron: 201
# Mining... Total Iron: 201
# Lifepod now has 201 iron.
# Greenhouse food reached max capacity: 100
# Engineer at (4, 0) is moving randomly.
# Agent rested. Current stamina: 10
# Engineer at (3, 1) is moving randomly.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 265 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 1, Drill Health: 1, Iron: 204
# Mining... Total Iron: 204
# Lifepod now has 204 iron.
# Engineer at (4, 2) is moving randomly.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 270 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 0, Drill Health: 0, Iron: 207
# Mining... Total Iron: 207
# Lifepod now has 207 iron.
# Agent rested. Current stamina: 10
# Agent rested. Current stamina: 10
# Miner at (8, 8) is resting to regain stamina.
# Greenhouse food reached max capacity: 100
# Engineer at (4, 2) moving towards broken drill at (9, 9).
# Engineer moved to (5, 3).
# Engineer at (5, 3) is moving towards the drill.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 275 food.
# Engineer at (5, 3) moving towards broken drill at (9, 9).
# Engineer moved to (6, 4).
# Engineer at (6, 4) is moving towards the drill.
# Available drills: []
# No drill found.
# Agent rested. Current stamina: 20
# Miner at (8, 8) is resting to regain stamina.
# Available drills: []
# No drill found.
# Agent rested. Current stamina: 30
# Miner at (8, 8) is resting to regain stamina.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 280 food.
# Greenhouse added 10 food. Total food: 100
# Engineer at (6, 4) moving towards broken drill at (9, 9).
# Engineer moved to (7, 5).
# Engineer at (7, 5) is moving towards the drill.
# Greenhouse food reached max capacity: 100
# Available drills: []
# No drill found.
# Agent rested. Current stamina: 40
# Miner at (8, 8) is resting to regain stamina.
# Agent rested. Current stamina: 10
# Engineer at (7, 5) moving towards broken drill at (9, 9).
# Engineer moved to (8, 6).
# Engineer at (8, 6) is moving towards the drill.
# Engineer at (8, 6) moving towards broken drill at (9, 9).
# Engineer moved to (9, 7).
# Engineer at (9, 7) is moving towards the drill.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 285 food.
# Available drills: []
# No drill found.
# Agent rested. Current stamina: 50
# Miner at (8, 8) is resting to regain stamina.
# Engineer at (9, 7) moving towards broken drill at (9, 9).
# Engineer moved to (9, 8).
# Engineer at (9, 8) is moving towards the drill.
# Available drills: []
# No drill found.
# Agent rested. Current stamina: 60
# Miner at (8, 8) is resting to regain stamina.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 290 food.
# Greenhouse food reached max capacity: 100
# Agent rested. Current stamina: 10
# Engineer at (9, 8) moving towards broken drill at (9, 9).
# Repairing drill at (9, 9).
# Engineer at (9, 8) repaired the drill at (9, 9).
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 68, Drill Health: 68, Iron: 210
# Mining... Total Iron: 210
# Lifepod now has 210 iron.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 67, Drill Health: 67, Iron: 213
# Mining... Total Iron: 213
# Lifepod now has 213 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 295 food.
# Engineer at (9, 7) is moving randomly.
# Greenhouse food reached max capacity: 100
# Engineer at (8, 8) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 66, Drill Health: 66, Iron: 216
# Mining... Total Iron: 216
# Lifepod now has 216 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 300 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 65, Drill Health: 65, Iron: 219
# Mining... Total Iron: 219
# Lifepod now has 219 iron.
# Greenhouse food reached max capacity: 100
# Engineer at (9, 9) is moving randomly.
# Agent rested. Current stamina: 10
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 64, Drill Health: 64, Iron: 222
# Mining... Total Iron: 222
# Lifepod now has 222 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 305 food.
# Greenhouse food reached max capacity: 100
# Engineer at (9, 0) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 310 food.
# Greenhouse food reached max capacity: 100
# Engineer at (9, 9) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 63, Drill Health: 63, Iron: 225
# Mining... Total Iron: 225
# Lifepod now has 225 iron.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 62, Drill Health: 62, Iron: 228
# Mining... Total Iron: 228
# Lifepod now has 228 iron.
# Greenhouse food reached max capacity: 100
# Agent rested. Current stamina: 10
# Engineer at (0, 0) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 315 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 61, Drill Health: 61, Iron: 231
# Mining... Total Iron: 231
# Lifepod now has 231 iron.
# Greenhouse food reached max capacity: 100
# Engineer at (9, 9) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 320 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 60, Drill Health: 60, Iron: 234
# Mining... Total Iron: 234
# Lifepod now has 234 iron.
# Engineer at (0, 9) is moving randomly.
# Greenhouse food reached max capacity: 100
# Engineer at (9, 8) is moving randomly.
# Agent rested. Current stamina: 10
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 59, Drill Health: 59, Iron: 237
# Mining... Total Iron: 237
# Lifepod now has 237 iron.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 58, Drill Health: 58, Iron: 240
# Mining... Total Iron: 240
# Lifepod now has 240 iron.
# Engineer at (8, 7) is moving randomly.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 325 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 57, Drill Health: 57, Iron: 243
# Mining... Total Iron: 243
# Lifepod now has 243 iron.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 330 food.
# Engineer at (9, 7) is moving randomly.
# Agent rested. Current stamina: 10
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 56, Drill Health: 56, Iron: 246
# Mining... Total Iron: 246
# Lifepod now has 246 iron.
# Engineer at (9, 8) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 55, Drill Health: 55, Iron: 249
# Mining... Total Iron: 249
# Lifepod now has 249 iron.
# Engineer at (9, 9) is moving randomly.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 335 food.
# Engineer at (8, 8) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 54, Drill Health: 54, Iron: 252
# Mining... Total Iron: 252
# Lifepod now has 252 iron.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 340 food.
# Greenhouse added 10 food. Total food: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 53, Drill Health: 53, Iron: 255
# Mining... Total Iron: 255
# Lifepod now has 255 iron.
# Engineer at (9, 9) is moving randomly.
# Agent rested. Current stamina: 10
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 345 food.
# Engineer at (8, 9) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 52, Drill Health: 52, Iron: 258
# Mining... Total Iron: 258
# Lifepod now has 258 iron.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 51, Drill Health: 51, Iron: 261
# Mining... Total Iron: 261
# Lifepod now has 261 iron.
# Greenhouse food reached max capacity: 100
# Engineer at (7, 8) is moving randomly.
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 350 food.
# Greenhouse food reached max capacity: 100
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 50, Drill Health: 50, Iron: 264
# Mining... Total Iron: 264
# Lifepod now has 264 iron.
# Agent rested. Current stamina: 10
# Engineer at (8, 9) is moving randomly.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 355 food.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 49, Drill Health: 49, Iron: 267
# Mining... Total Iron: 267
# Lifepod now has 267 iron.
# Engineer at (8, 0) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 48, Drill Health: 48, Iron: 270
# Mining... Total Iron: 270
# Lifepod now has 270 iron.
# Greenhouse food reached max capacity: 100
# Farmer collected 5 food from greenhouse at (1, 5).
# Lifepod now has 360 food.
# Engineer at (7, 0) is moving randomly.
# Greenhouse food reached max capacity: 100
# Engineer at (8, 1) is moving randomly.
# Available drills: [(9, 9)]
# Nearest drill found at (9, 9)
# Miner at (8, 8) moving towards drill at (9, 9)
# Miner is near the drill at (9, 9). Starting to mine.
# Drill is functional, starting mining.
# Mining... Drill Fuel: 47, Drill Health: 47, Iron: 273
# Mining... Total Iron: 273
# Lifepod now has 273 iron.
# Agent rested. Current stamina: 10

# %%
model_data = model.datacollector.get_model_vars_dataframe() 
print(model_data)
# Out:
#     Total Food  Total Iron  Drill Health  Drill Fuel  Greenhouse Food  \
# 0           20           0            69          69                0
# 1           20           0            69          69               10
# 2           20           0            69          69               20
# 3           20           0            69          69               30
# 4           20           3            68          68               40
# ..         ...         ...           ...         ...              ...
# 95         345         258            52          52              100
# 96         350         261            51          51               95
# 97         350         264            50          50              100
# 98         355         267            49          49               95
# 99         360         270            48          48               95
#
#     Miner Stamina  Engineer Stamina  Farmer Stamina  \
# 0              69                69              69
# 1              69                69              69
# 2              69                69              69
# 3              69                69              69
# 4              68                69              69
# ..            ...               ...             ...
# 95             43                59               5
# 96             42                59               0
# 97             41                59              10
# 98             40                59               5
# 99             39                59               0
#
#                                         Cell Contents
# 0   {(0, 0): [], (0, 1): [], (0, 2): [], (0, 3): [...
# 1   {(0, 0): [], (0, 1): [], (0, 2): [], (0, 3): [...
# 2   {(0, 0): [], (0, 1): [], (0, 2): [], (0, 3): [...
# 3   {(0, 0): [], (0, 1): [], (0, 2): [], (0, 3): [...
# 4   {(0, 0): [], (0, 1): [], (0, 2): [], (0, 3): [...
# ..                                                ...
# 95  {(0, 0): [], (0, 1): [], (0, 2): [], (0, 3): [...
# 96  {(0, 0): [], (0, 1): [], (0, 2): [], (0, 3): [...
# 97  {(0, 0): [], (0, 1): [], (0, 2): [], (0, 3): [...
# 98  {(0, 0): [], (0, 1): [], (0, 2): [], (0, 3): [...
# 99  {(0, 0): [], (0, 1): [], (0, 2): [], (0, 3): [...
#
# [100 rows x 9 columns]
